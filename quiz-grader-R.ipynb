# %% [markdown]
# # Preparation

# %%
# Input Here

import pandas as pd

QUIZ_DF = pd.read_csv("ProgrammingforDataScienceandPracticalStatistics-all_0.csv") # Quiz CSV Path

SCORE_ACADEMY_LINK = 'https://docs.google.com/spreadsheets/d/1cGJ0pn9k9gKCBnceWVwaL9D7BBDMNjLh8uPYlaBlJi8/edit?usp=sharing' # Score Academy Link
NAMA_SHEET = "Dummy" #"Academy: Batch 23" # Sheet Name (Wizard)

# %% [markdown]
# Import required dependencies to use Google's API

# %%
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %% [markdown]
# Define the accesses to be granted

# %%
SCOPES = ['https://www.googleapis.com/auth/classroom.courses.readonly', # View your Google Classroom classes.
          'https://www.googleapis.com/auth/classroom.rosters', # Manage your Google Classroom class rosters.
          'https://www.googleapis.com/auth/classroom.profile.emails', # View the email addresses of people in your classes.
          'https://www.googleapis.com/auth/classroom.topics', #See, create, and edit topics in Google Classroom.
          'https://www.googleapis.com/auth/classroom.coursework.students', # Manage coursework and grades for students
          'https://www.googleapis.com/auth/classroom.courseworkmaterials', # See, edit, and create classwork materials in Google Classroom.
          'https://www.googleapis.com/auth/spreadsheets'] # See all your Google Sheets spreadsheets.

# %% [markdown]
# Use the provided `token.json` file to authenticate and access user data, if `token.json` is not available, it would be created from the provided `credentials.json` by logging into user's Google Account

# %%
creds = None

if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())

# %% [markdown]
# # Score Academy
#
# In the section, the user is going to access the scores that have been entered on the spreadsheet `Score Academy`

# %% [markdown]
# Input the link to the Score Academy spreadsheet and retrieve the Spreadsheet ID

# %%
SCORE_ACADEMY_ID = SCORE_ACADEMY_LINK.split(sep='/')[-2]

# %% [markdown]
# Specify the sheet and the cell ranges that is going to be accessed

# %%
GRADE_RANGE = [f'{NAMA_SHEET}!D:E', f'{NAMA_SHEET}!F:H', f'{NAMA_SHEET}!M:R']

# %% [markdown]
# Call the Google Spreadsheet API and retrieve the values of the ranges that have been specified

# %%
try:
    service = build('sheets', 'v4', credentials=creds)

    sheet = service.spreadsheets().values().batchGet(spreadsheetId=SCORE_ACADEMY_ID,
                                                     ranges=GRADE_RANGE).execute()
    values = sheet.get('valueRanges', [])
        
except HttpError as error:
    print(error)

# %% [markdown]
# Concat the retrieved values as a dataframe

# %%
import pandas as pd

email = pd.DataFrame(values[0].get('values'))
grade_dv = pd.DataFrame(values[1].get('values'))
grade_ml = pd.DataFrame(values[2].get('values'))

df = pd.concat([email, grade_dv, grade_ml], axis=1)
df.columns = df.iloc[0]
df.drop(index=0, inplace=True)

df
# Out:
# 0                                 Email                Email Classroom  \
# 1            danadyaksawijaya@gmail.com     danadyaksawijaya@gmail.com
# 2                 berlianahar@gmail.com          berlianahar@gmail.com
# 3                angiegrace35@gmail.com         angiegrace35@gmail.com
# 4          ihsan.azmi.rabbani@gmail.com   ihsan.azmi.rabbani@gmail.com
# 5                  lhpratama2@gmail.com           lhpratama2@gmail.com
# 6                melissa.offc@gmail.com         melissa.offc@gmail.com
# 7               nadyanaftalia@gmail.com        nadyanaftalia@gmail.com
# 8               brenda.thadete@live.com       brenda.thadete@gmail.com
# 9                  ghozyaufan@gmail.com           ghozyaufan@gmail.com
# 10                kambu.charles@aol.com        kambu.charles@gmail.com
# 11              audichandra94@gmail.com        audichandra94@gmail.com
# 12   Calvin.gozal@component.astra.co.id          calvingozal@gmail.com
# 13              senddimasadit@gmail.com        senddimasadit@gmail.com
# 14          zhafarfarhan.work@gmail.com    zhafarfarhan.work@gmail.com
# 15        ellen.setiawan@corp.bri.co.id     vinsensiaellen10@gmail.com
# 16                faza.aliyab@gmail.com          Faza.AliyaB@gmail.com
# 17  fransiska.jesinta@brilian.bri.co.id     jesintafransiska@gmail.com
# 18            cakmustafa@unissula.ac.id           cakmustafa@gmail.com
# 19     Nia.Dewinofianti@btpnsyariah.com    niadewinofianti18@gmail.com
# 20        lazuardi.pramadia@outlook.com    pramadia.lazuardi@gmail.com
# 21            ranno.chairandy@gmail.com      ranno.chairandy@gmail.com
# 22          ridha.rahmi@btpnsyariah.com          rahmi.ridha@gmail.com
# 23         shavira.z@massivemusic.co.id         szhalsabilla@gmail.com
# 24                  wildanziq@gmail.com            wildanziq@gmail.com
# 25        fathiyyah.maryufani@gmail.com  fathiyyah.maryufani@gmail.com
# 26             patrapembinaan@gmail.com       patrapembinaan@gmail.com
# 27        bintang.setyawan@peruri.co.id          binsetyawan@gmail.com
# 28               fajarkhamim6@gmail.com         fajarkhamim6@gmail.com
# 29         gustaf.yulianto@pgncom.co.id       gustafyulianto@gmail.com
# 30             husnaaydadenta@gmail.com              haydnta@gmail.com
# 31       trishna.fadea@digitalperuri.id        trishna.fadea@gmail.com
# 32               fafafauzan30@gmail.com         fafafauzan30@gmail.com
# 33                albertusmpp@gmail.com          albertusmpp@gmail.com
# 34           baguspramudito92@gmail.com     baguspramudito92@gmail.com
# 35               fenny_martan@yahoo.com          martanfenny@gmail.com
# 36              Hendrychai.id@gmail.com        hendrychai.id@gmail.com
# 37          jayadidetormentor@gmail.com    jayadidetormentor@gmail.com
# 38                   lelanovi@gmail.com             LelaNovi@gmail.com
# 39                ncorlidea99@gmail.com          ncorlidea99@gmail.com
# 40                osim.olivia@gmail.com          osim.olivia@gmail.com
# 41           kunciran_sakti@yahoo.co.uk    pandukukunforwork@gmail.com
# 42              riyansasmytha@gmail.com        riyansasmytha@gmail.com
# 43                adhi.taufan@gmail.com           tf.anggoro@gmail.com
# 44              satyopradana1@gmail.com        satyopradana1@gmail.com
# 45                  taufiq234@yahoo.com            taufiq234@gmail.com
# 46            theophilos.rico@gmail.com      theophilos.rico@gmail.com
# 47          louis.albert@rocketmail.com         louis.sirait@gmail.com
#
# 0  P4DS-PS Quiz DV Quiz IP Quiz RM Quiz C1 Quiz C2 Quiz UL Quiz TS Quiz  \
# 1             4       2    None     NaN     NaN     NaN     NaN     NaN
# 2             4       2    None     NaN     NaN     NaN     NaN     NaN
# 3             4       2    None     NaN     NaN     NaN     NaN     NaN
# 4             4       2    None     NaN     NaN     NaN     NaN     NaN
# 5             4       2    None     NaN     NaN     NaN     NaN     NaN
# 6             4       2    None     NaN     NaN     NaN     NaN     NaN
# 7             4       2    None     NaN     NaN     NaN     NaN     NaN
# 8             4       2    None     NaN     NaN     NaN     NaN     NaN
# 9             4       2    None     NaN     NaN     NaN     NaN     NaN
# 10            4       0    None     NaN     NaN     NaN     NaN     NaN
# 11            4       2    None     NaN     NaN     NaN     NaN     NaN
# 12            4       2    None     NaN     NaN     NaN     NaN     NaN
# 13            0       0    None     NaN     NaN     NaN     NaN     NaN
# 14            4       2    None     NaN     NaN     NaN     NaN     NaN
# 15            4       2    None     NaN     NaN     NaN     NaN     NaN
# 16            4       2    None     NaN     NaN     NaN     NaN     NaN
# 17            4       2    None     NaN     NaN     NaN     NaN     NaN
# 18            4       2    None     NaN     NaN     NaN     NaN     NaN
# 19            4       2    None     NaN     NaN     NaN     NaN     NaN
# 20            4       2    None     NaN     NaN     NaN     NaN     NaN
# 21            4       2    None     NaN     NaN     NaN     NaN     NaN
# 22            4       2    None     NaN     NaN     NaN     NaN     NaN
# 23            4       2    None     NaN     NaN     NaN     NaN     NaN
# 24            4       2    None     NaN     NaN     NaN     NaN     NaN
# 25            4       2    None     NaN     NaN     NaN     NaN     NaN
# 26            4       0    None     NaN     NaN     NaN     NaN     NaN
# 27            0       0    None     NaN     NaN     NaN     NaN     NaN
# 28            4       2    None     NaN     NaN     NaN     NaN     NaN
# 29            0       0    None     NaN     NaN     NaN     NaN     NaN
# 30            4       2    None     NaN     NaN     NaN     NaN     NaN
# 31            4       2    None     NaN     NaN     NaN     NaN     NaN
# 32            4       2    None     NaN     NaN     NaN     NaN     NaN
# 33            4       2    None     NaN     NaN     NaN     NaN     NaN
# 34            4       2    None     NaN     NaN     NaN     NaN     NaN
# 35            0       0    None     NaN     NaN     NaN     NaN     NaN
# 36            4       2    None     NaN     NaN     NaN     NaN     NaN
# 37            4       2    None     NaN     NaN     NaN     NaN     NaN
# 38            4       2    None     NaN     NaN     NaN     NaN     NaN
# 39            4       2    None     NaN     NaN     NaN     NaN     NaN
# 40            4       2    None     NaN     NaN     NaN     NaN     NaN
# 41            4       2    None     NaN     NaN     NaN     NaN     NaN
# 42            4       2    None     NaN     NaN     NaN     NaN     NaN
# 43            4       2    None     NaN     NaN     NaN     NaN     NaN
# 44            4       2    None     NaN     NaN     NaN     NaN     NaN
# 45            4       2    None     NaN     NaN     NaN     NaN     NaN
# 46            4       0    None     NaN     NaN     NaN     NaN     NaN
# 47            4       2    None     NaN     NaN     NaN     NaN     NaN
#
# 0  NN Quiz
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# 40     NaN
# 41     NaN
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN

# %% [markdown]
# # Course
# In this section, the user is going to choose which Google Classroom Course that is going to be accessed

# %% [markdown]
# Call the Google Classroom API to access various methods with user's access from the credential that has been authenticated

# %%
service = build('classroom', 'v1', credentials=creds)

# %% [markdown]
# Use the `courses().list()` method to show a list of the user's courses

# %%
results = service.courses().list(pageSize=5).execute()
courses = results.get('courses', [])

if not courses:
    print('No courses found.')

# Prints the names of the first 5 courses.
print('Courses:')
for course in courses:
    print(f"- {course['name']}")
# Out:
# Courses:
# - Wizard Machine Learning
# - Wizard Data Visualization
# - Kementerian BUMN
# - Automation
# - Wizard Data Analytics

# %% [markdown]
# Input the course name (**case-insensitive**) that is going to be accessed (Example: `wizard data visualization`). If the course was found, the course's `id` will be retrieved.

# %%
course_input = input("Enter Google Classroom Class Name : ")
course_lowercase = course_input.lower()
course_id = None

for course in courses:
    if course_lowercase == course['name'].lower():
        course_id = course['id']
        break

if course_id == None:
    raise Exception(f"{course_input} course not found")

else:
    print(f'{course_input} found with ID {course_id}')
# Out:
# Wizard Data Visualization found with ID 621398536690

# %% [markdown]
# # Quiz
# In this section, the grading process is going to be done using the score retrieved from the spreadsheet

# %% [markdown]
# Input the quiz code (**case-insensitive**) that is going to be accessed. If the quiz was found, the quiz's `id` will be retrieved. **Quiz Input :**
#
#  - `'P4DS'` : 1. Q: Programming for Data Science (P4DS) & Practical Statistic (PS)
#  - `'DV'` : 2. Q: Data Visualization (DV)
#  - `'IP'` : 3. Q: Interactive Plotting (IP)

# %%
from assets import classcode, max_score

service = build('classroom', 'v1', credentials=creds)
response = service.courses().courseWork().list(courseId=course_id).execute()
classworks = response.get('courseWork')

while response.get('nextPageToken'):
    response = service.courses().students().list(courseId=course_id, pageToken = response['nextPageToken']).execute()
    classworks.extend(response.get('courseWork'))

quiz_input = input("Enter Quiz Code: ")
quiz_id = None

for classwork in classworks:
    if classwork['title'] == classcode(quiz_input):
        quiz_id = classwork['id']
        break

if quiz_id == None:
    raise Exception(f"Quiz not found")
else:
    print(f"{classwork['title']} Quiz was found")
# Out:
# 2. Q: Data Visualization (DV) Quiz was found

# %% [markdown]
# # Write Score Academy
#
# In this section, the received grade is going to be written in Score Academy

# %%
QUIZ_DF['USER EMAIL'] = QUIZ_DF['USER EMAIL'].str.strip().str.lower()
QUIZ_DF['PASSED STATUS'] = QUIZ_DF['PASSED STATUS'].str.strip().str.lower()
QUIZ_DF = QUIZ_DF[QUIZ_DF['PASSED STATUS'] == "yes"]
QUIZ_DF = QUIZ_DF.drop_duplicates("USER EMAIL")
passed_email = QUIZ_DF["USER EMAIL"]

passed_email
# Out:
# 0          binsetyawan@gmail.com
# 1           ghozyaufan@gmail.com
# 3      theophilos.rico@gmail.com
# 4        nadyanaftalia@gmail.com
# 5            wildanziq@gmail.com
#                  ...
# 690       samuelmulia2@gmail.com
# 694              lita@algorit.ma
# 696      adyatama.arga@gmail.com
# 703     davidlimbonggg@gmail.com
# 708       trianinarita@gmail.com
# Name: USER EMAIL, Length: 640, dtype: object

# %%
passed_email.values
# Out:
# array(['binsetyawan@gmail.com', 'ghozyaufan@gmail.com',
#        'theophilos.rico@gmail.com', 'nadyanaftalia@gmail.com',
#        'wildanziq@gmail.com', 'cakmustafa@unissula.ac.id',
#        'ridha.rahmi@btpnsyariah.com', 'fafafauzan30@gmail.com',
#        'trishna.fadea@digitalperuri.id', 'husnaaydadenta@gmail.com',
#        'nia.dewinofianti@btpnsyariah.com',
#        'calvin.gozal@component.astra.co.id', 'satyopradana1@gmail.com',
#        'brenda.thadete@live.com', 'zhafarfarhan.work@gmail.com',
#        'riyansasmytha@gmail.com', 'jayadidetormentor@gmail.com',
#        'shavira.z@massivemusic.co.id', 'kunciran_sakti@yahoo.co.uk',
#        'louis.albert@rocketmail.com', 'ranno.chairandy@gmail.com',
#        'lazuardi.pramadia@outlook.com', 'taufiq234@yahoo.com',
#        'osim.olivia@gmail.com', 'kambu.charles@aol.com',
#        'audichandra94@gmail.com', 'fransiska.jesinta@brilian.bri.co.id',
#        'albertusmpp@gmail.com', 'ncorlidea99@gmail.com',
#        'faza.aliyab@gmail.com', 'fajarkhamim6@gmail.com',
#        'berlianahar@gmail.com', 'ihsan.azmi.rabbani@gmail.com',
#        'danadyaksawijaya@gmail.com', 'lelanovi@gmail.com',
#        'angiegrace35@gmail.com', 'adhi.taufan@gmail.com',
#        'melissa.offc@gmail.com', 'baguspramudito92@gmail.com',
#        'hendrychai.id@gmail.com', 'lhpratama2@gmail.com',
#        'fathiyyah.maryufani@gmail.com', 'ellen.setiawan@corp.bri.co.id',
#        'bagus6705@gmail.com', 'afrillian.rudi@fli.co.id',
#        'faiz.faisal.ahmad@gmail.com', 'brian.a.gunardi@gmail.com',
#        'azwar.aziz79@gmail.com', 'go4earl@yahoo.co.uk',
#        'brandantitor@gmail.com', 'hanifahp.lestari@gmail.com',
#        'bayaubay.83@gmail.com', 'isaiahabib@gmail.com',
#        'cahyo.widodo@agel.co.id', 'gittacarmenia@gmail.com',
#        'christopher.aninditya.a@gmail.com', 'ambarishalayang@gmail.com',
#        'matthewbradleylo2002@gmail.com', 'richard.susanto1620@gmail.com',
#        'ratnadewi.monica@gmail.com', 'nugra.aditya96@gmail.com',
#        'valmaythrh@gmail.com', 'lonexindo@yahoo.com',
#        'kintari2000@gmail.com', 'amrisidiq@gmail.com',
#        'yuliristiana12@gmail.com', 'rusdipermana2@gmail.com',
#        'deforuu@gmail.com', 'ppic.op.sda@kapalapi.co.id',
#        'afifmhd23@gmail.com', 'sahidhindralaksana@gmail.com',
#        'aninditaksma@gmail.com', 'akmalgoritma@gmail.com',
#        'renaldirefsy@gmail.com', 'gustrindah@gmail.com',
#        'thegreatardian@gmail.com', 'wnofrizal46@gmail.com',
#        'afrilian46@gmail.com', 'edwinraisss@gmail.com',
#        'teguh@agel.co.id', 'iraraliayasfri55.iry@gmail.com',
#        'carli@fli.co.id', 'qa3@kapalapi.co.id',
#        'ricardo.julian@kapalapi.co.id', 'alfonsa.cindy@kapalapi.co.id',
#        'beladina.novia@gmail.com', 'bima.35.bim@gmail.com',
#        'patrapembinaan@gmail.com', 'dhita.tyo0405@gmail.com',
#        'nadhif.naufal@gmail.com', 'nadyasarinastiti@gmail.com',
#        'anggaistighfar@gmail.com', 'michael.chen@kapalapi.co.id',
#        'dianaoffice35@gmail.com',
#        'hananfarizta@student.telkomuniversity.ac.id',
#        'mrivay123@gmail.com', 'georgerico4337@gmail.com',
#        'swastika.nata1804@gmail.com', 'sitorushedrin@gmail.com',
#        'nabbilgibranwe@gmail.com', 'sintarios000@gmail.com',
#        'thesion.jambi2018@gmail.com', 'bryanvergus@gmail.com',
#        'putriginting35@gmail.com', 'faiqazmi444@gmail.com',
#        'edbertfernando6@gmail.com', 'srenaldd@gmail.com',
#        'andrew.anggoh@gmail.com', 'melfinalfan@gmail.com',
#        'nurimammasri.01@gmail.com', 'ophank.atthoriq@gmail.com',
#        'hanifmmufid@gmail.com', 'hairulyadin@gmail.com',
#        'arnolds1809@gmail.com', 'fikhoni@gmail.com',
#        'akmalfauzi001@gmail.com', 'fadhilamar23@gmail.com',
#        'ilyashaikall02@gmail.com', 'gustana.satiawan@gmail.com',
#        'rizkypadilah180@gmail.com', 'robby7sn@gmail.com',
#        'fajar.kholik@my.sampoernauniversity.ac.id',
#        'putri.nurulhasanah11@gmail.com', 'ahmad.sirrullah.b@gmail.com',
#        'petergiovanno21@gmail.com', 'david.wilson19.dws@gmail.com',
#        'chandrap.angga@gmail.com', 'dimasalif5@gmail.com',
#        'ilyashibaet@gmail.com', 'khoirunnisahamidah17@gmail.com',
#        'rentasitorus28@gmail.com', 'rzzkalldi@gmail.com',
#        'dhoniapriyadi19@gmail.com', 'jalludimas@gmail.com',
#        'marthaangel@apps.ipb.ac.id', 'caysonadley@gmail.com',
#        'sarahoctavia8@gmail.com', 'kenangghalih21@gmail.com',
#        'tiosyaifuddinlo@gmail.com', 'syahvanalviansyah91@gmail.com',
#        'michelleintan99@gmail.com', 'wrk.ahmadfauzi@gmail.com',
#        'themostzahra@gmail.com', 'ozy.prazugandaa@gmail.com',
#        'ayupatresianababan@gmail.com', 'alexander.budiman@mail.ugm.ac.id',
#        'freddyfrinlysky@gmail.com', 'yumawan76@gmail.com',
#        'priyanty.nurul@ui.ac.id', 'irwan.haryanto88@gmail.com',
#        'firmanuur.i@gmail.com', 'qlik.dev@sariroti.com',
#        'david.simamora@gmail.com', 'budiman8503@gmail.com',
#        'hasibuan2392@gmail.com', 'l.tresya@gmail.com',
#        'satiti.palupi@yahoo.co.id', 'harsongko@gmail.com',
#        'juliusrbudiman@gmail.com', 'kurniawan.febrianto@gmail.com',
#        'mffadhlurrohmanfaqih@gmail.com', 'yogidwitama07@gmail.com',
#        'mariana.katrina@gmail.com', 'taniaangelia98@gmail.com',
#        'annerina84@gmail.com', 'erwans0909@gmail.com',
#        'zefanyahermanta@gmail.com', 'trideria.kenia@gmail.com',
#        'bagus.ismujati@gmail.com', 'riksa617@gmail.com',
#        'nur.fadiyah@outlook.com', 'genoveva.kameubun03@gmail.com',
#        'affandrytaufik@gmail.com', 'ejhasiadari@gmail.com',
#        'azizrizal888@protonmail.com', 'delv283@gmail.com',
#        'rajapalawija@gmail.com', 'moses.nugraha01@gmail.com',
#        'suwarnoasmadi@gmail.com', 'nicosyuu@gmail.com',
#        'rickyarians@outlook.com', 'ikhromi@gmail.com',
#        'tammya.ayu@gmail.com', 'alex.gelfand941@gmail.com',
#        'faisal.adhisthana@gmail.com', 'heinzmdsiahaan@gmail.com',
#        'lycia.pricia@kemkes.go.id', 'triungko@gmail.com',
#        'deanalexander1998@gmail.com', 'yan_kusumo@bca.co.id',
#        'murphy_halim@bca.co.id', 'ikanurfariha@gmail.com',
#        'sultanardiansyah26@gmail.com', 'reni.unisa@gmail.com',
#        'adlirikanda@gmail.com', 'rudi_kule@unsri.ac.id',
#        'ryanfitraperdana@unsri.ac.id', 'noordinasshiddiq@unsri.ac.id',
#        'chandraes@unsri.ac.id', 'ahmad.mudhoffar@brilian.bri.co.id',
#        'achmad.shivan@corp.bri.co.id', 'liviaserevina@gmail.com',
#        'hansjo.fc@gmail.com', 'danteistanto2002@yahoo.com',
#        'riimaasugiarto@gmail.com', 'galihwardiana@gmail.com',
#        'wiraachandra@gmail.com', 'chaidaraji@gmail.com',
#        'davidwidyanto8@gmail.com', 'bkaryadi93@gmail.com',
#        'faisal.amir81@ui.ac.id', 'eri.wahyudi@hanwhalife.co.id',
#        'dimashrp@gmail.com', 'angelaursula11@gmail.com',
#        'mfadhil.abdullah95@gmail.com', 'jmynath@gmail.com',
#        'salmanabilah1607@gmail.com', 'mirfani28bdg@gmail.com',
#        'dinarabalqis@gmail.com', 'reyhanpurnawan@gmail.com',
#        'alfandara.kevin@gmail.com', 'ali.rdhani@gmail.com',
#        'rafamagnarvirendra@gmail.com', 'benhardi.kristian@gmail.com',
#        'ramdanitriastoto@gmail.com', 'bagashardojo20@gmail.com',
#        'luthfan.wakan@gmail.com', 'danielwijoyo.suharso@gmail.com',
#        'purnomowasis@gmail.com', 'dessyfvr@gmail.com',
#        'muhammadridhwan0408@gmail.com', 'yoohanespm@gmail.com',
#        'ageljonathans@gmail.com', 'furqanakbar.n@gmail.com',
#        'muhammadrafif3225@gmail.com', 'ramdani.safier@gmail.com',
#        'aldiirianto999@gmail.com',
#        'chrisantonius@bpjsketenagakerjaan.go.id',
#        'nurinaswgotami@gmail.com', 'andanawesthi@gmail.com',
#        'samgoesniady@gmail.com', 'mssasholah@gmail.com',
#        'rinoanthonystiawan@gmail.com', 'chevsiman@gmail.com',
#        'tarumainfo@gmail.com', 'taliathaib@gmail.com',
#        'rizkycitraramadhan@gmail.com', 'yohanesegipratama@gmail.com',
#        'robert@kawansehatindonesia.com', 'jamagis1897@gmail.com',
#        'igni.kevin@gmail.com', 'destianfa@gmail.com',
#        'dicky.larsond@gmail.com', 'herlantoesitompul@gmail.com',
#        'arnaldo_putra@bca.co.id', 'alexander_jhonatan@bca.co.id',
#        'panji_stephanus@bca.co.id', 'charoline_ayu@bca.co.id',
#        'patrisia_njoo@bca.co.id', 'ninyoman_triwahyuni@bca.co.id',
#        'william_soerjady@bca.co.id', 'jhonny_jonatan@bca.co.id',
#        'frederica_waruwu@bca.co.id', 'lauwra_agustine@bca.co.id',
#        'edric_wijaya@bca.co.id', 'steven_novianus@bca.co.id',
#        'maria_sekar@bca.co.id', 'evelyn_meilinda@bca.co.id',
#        'stephanie_carissa@bca.co.id', 'revina_claresta@bca.co.id',
#        'hartanti_josephine@bca.co.id', 'andrew_jonathan@bca.co.id',
#        'claudia_susilo@bca.co.id', 'carinna_darmawan@bca.co.id',
#        'nadya_tindagi@bca.co.id', 'nicholas_setyabudi@bca.co.id',
#        'yohanna_karina@bca.co.id', 'vanessa_dipo@bca.co.id',
#        'kurniawan_salim@bca.co.id', 'dominicus_kristiawan@bca.co.id',
#        'jeasline_linarta@bca.co.id', 'finsa_sani@bca.co.id',
#        'jeremia_michael@bca.co.id', 'yani_listiyani@bca.co.id',
#        'agnes_hata@bca.co.id', 'agustinus_aji@bca.co.id',
#        'cosmas_nugroho@bca.co.id', 'vincent_fady@bca.co.id',
#        'timothy_laxmana@bca.co.id', 'ibrahim_resa@bca.co.id',
#        'floretta_tano@bca.co.id', 'aurelia_santoso@bca.co.id',
#        'amalia_khadariyah@bca.co.id', 'lia_puspita@bca.co.id',
#        'erni_soeharto@bca.co.id', 'syerly_setiana@bca.co.id',
#        'rosalineanastasya98@gmail.com', 'tanalvianadams@gmail.com',
#        'jason_widjaja@bca.co.id', 'maria_beata@bca.co.id',
#        'keely_hasim@bca.co.id', 'garry_arimurti@bca.co.id',
#        'nathasia_efendi@bca.co.id', 'kemas.pratama@lps.go.id',
#        'evioktavia76@yahoo.com', 'benoafryan@gmail.com',
#        'aryadananjaya23@gmail.com', 'tpramasto@gmail.com',
#        'f-sutanto@tigaraksa.co.id', 'bayu.utama94@gmail.com',
#        'nipututasya88@gmail.com', 'galuh.sanristia@kordsa.com',
#        'mirnadwi67@gmail.com', 'rahmad.sanjaya@lps.go.id',
#        'debb.sanjaya08@gmail.com', 'hanifah.laili@lps.go.id',
#        'rizalhamim@gmail.com', 'indra.ramadhan@kordsa.com',
#        'muhammadnabilasykar34@gmail.com', 'annisanurdiana9@gmail.com',
#        'fikri.rizal.aq@gmail.com', 'andhika.b.hermawan@gmail.com',
#        'carlioseryan20@gmail.com', 'yektipratiwi.study@gmail.com',
#        'viyanti.trianta@gmail.com', 'fxpeterbs31@gmail.com',
#        'tu849035@gmail.com', 'rachmatm@gmail.com',
#        'satriayonvi20@gmail.com', 'novarinoshindy@gmail.com',
#        'hayykal99@gmail.com', 'christina.paroke@shopback.com',
#        'dito.hermadi@lps.go.id', 'laurensius.n@lps.go.id',
#        'sunarwan_asuhadi@yahoo.com', 'kukuh.susanto@kapalapi.co.id',
#        'libertus2808@gmail.com', 'yulekristina@gmail.com',
#        'milhamwhyd@gmail.com', 'athaisyah@yahoo.com',
#        'vetricko@gmail.com', 'purwto3369@gmail.com',
#        'gamaginta.gamaginta@lps.go.id', 'pandu.prabowo.jati@gmail.com',
#        'baidaiqlima@gmail.com', 'dieki.rian.mustapa@gmail.com',
#        'dplgum@gmail.com', 'angelia.inge@gmail.com', 'kozisaf@gmail.com',
#        'jerri.ali@lps.go.id', 'albert.wsurjana@gmail.com',
#        'christonindyo@gmail.com', 'namirasuniaprita07@gmail.com',
#        'mikha.kristofer@gmail.com', 'mula.simanjuntak@gmail.com',
#        'sab.brina3110@gmail.com', 'farabisuhud@gmail.com',
#        'david.andriyan@gmail.com', 'gemilang.rangga94@gmail.com',
#        'w.mahendra@outlook.com', 'arief_trigunawan@airmancur.co.id',
#        'adeanggins@gmail.com', 'takdirzd18@gmail.com',
#        'toniandreassusanto1209@gmail.com', 'daryrama@gmail.com',
#        'mesanda@gmail.com', 'revado_hutagaol@bca.co.id',
#        'david_sihombing@bca.co.id', 'ria_setiani@bca.co.id',
#        'ade_pratama@bca.co.id', 'angel_karentia@bca.co.id',
#        'agnes_sutjipto@bca.co.id', 'tennia_reydita@bca.co.id',
#        'eldora_lintang@bca.co.id', 'edrik_antolis@intra.bca',
#        'mariam_gouw@bca.co.id', 'reza_pratama@bca.co.id',
#        'vania_risriani@bca.co.id', 'phelia_salim@bca.co.id',
#        'jessica_paradina@bca.co.id', 'peter_kambey@bca.co.id',
#        'tebuana_putra@bca.co.id', 'franky_yulistian@bca.co.id',
#        'christopher_lay@bca.co.id', 'ewen_liam@bca.co.id',
#        'aditya_nugroho@bca.co.id', 'reiner_surja@bca.co.id',
#        'andre_julius@bca.co.id', 'andika_bhakti@bca.co.id',
#        'brigitta_limantoro@bca.co.id', 'junaidy_jonathan@bca.co.id',
#        'dionisius_saviordo@intra.bca', 'sukirman15@pusri.co.id',
#        'satriomuhammad82@gmail.com', 'anisanatalia88@gmail.com',
#        'arief.ashidiqi@unilever.com', 'reymonza07@gmail.com',
#        'manurung.herman@gmail.com', 'dhiafs.bnis@gmail.com',
#        'rofiemuh@gmail.com', 'shaun.kumulia@gmail.com',
#        'maximalyono@gmail.com', 'adrianpratama01@gmail.com',
#        'adi.prabowo@icloud.com', 'dedepradanatax@gmail.com',
#        'agusprojects@gmail.com', 'fajar@lps.go.id',
#        'oktriunitha@gmail.com', 'sukirboy@gmail.com',
#        'melanihariyono@gmail.com', 'ridhohilmansyah@gmail.com',
#        'olgasihombing@gmail.com', 'indra.perdana@gmail.com',
#        'rahmamualifa@gmail.com', 'gaostipkialpandi@gmail.com',
#        'azharizzannadae@gmail.com', 'gitarosa14@gmail.com',
#        'elvikhairunnisa@gmail.com', 'izzuabd@gmail.com',
#        'bintangzagarino@gmail.com', 'alviankhairi2019@gmail.com',
#        'frengkylanggeng@gmail.com', 'adhiperdanaputra@gmail.com',
#        'foursong.group@gmail.com', 'irfan.nurfalah@gmail.com',
#        'vandiahmad24@gmail.com', 'alver-berlianta.mahdapati@unilever.com',
#        'doni.sukarno@gmail.com', 'tioyudhapermana@gmail.com',
#        'andreas.and.q@gmail.com', 'senaaji21@gmail.com',
#        'mitaartmitaart@gmail.com', 'yohanapetrah@gmail.com',
#        'ardihr89@gmail.com', 'kafani.irawan@lps.go.id',
#        'metha.sipayung@saint-gobain.com', 'saramonica88@gmail.com',
#        'pranatiawisnuheryuda@gmail.com',
#        'rizky.adhityaputra@cimbniaga.co.id', 'navaanuau@gmail.com',
#        'vivianlimm8@gmail.com', 'fatwa131199@gmail.com',
#        'rahmarahma@apps.ipb.ac.id', 'ilmamiraaa@gmail.com',
#        'hanselianihutabarat@gmail.com', 'dwiretnof88@gmail.com',
#        'wennie.zhang123@gmail.com', 'edberthalim29@gmail.com',
#        'reynaldihutapea15@gmail.com', 'rulierin@gmail.com',
#        'eldiolangkun@gmail.com', 'husadahertzsprung@gmail.com',
#        'cher.pi@gmail.com', 'myusufibrahim@outlook.com',
#        'jeremiaww@gmail.com', 'radityafiqa4@gmail.com',
#        'ivan.shindunata@kalbenutritionals.com', 'agungtata89@gmail.com',
#        'rizkimahardika37@gmail.com', 'hilman.radifan@kitalulus.com',
#        'cliff.atmadja@gmail.com', 'safirawdyp@gmail.com',
#        'aditya.ditro93@gmail.com', 'frachmania0116@pnm.co.id',
#        'danusata95@gmail.com', 'sarah.budiyani@ptsmi.co.id',
#        'afwan.dachlan@gmail.com', 'adriana.juwita@kalbenutritionals.com',
#        'mhmmdhnfibrhm@gmail.com', 'jodiebintang1@gmail.com',
#        'shellatheresya@gmail.com', 'jefy_lin@bca.co.id',
#        'eilyn_widodo@bca.co.id', 'william_hadisaputra@bca.co.id',
#        'ferensius_reynaldi@bca.co.id', 'maria_mursitorini@bca.co.id',
#        'stephanie_chandra@bca.co.id', 'ignatiuswaluya@gmail.com',
#        'josephine_aditio@bca.co.id', 'hilarius_pamungkas@bca.co.id',
#        'fakhrana_giovana@bca.co.id', 'jhery_sitepu@bca.co.id',
#        'frederik_amiko@bca.co.id', 'cynthia_alivia@bca.co.id',
#        'novelinda_aulia@bca.co.id', 'jessica_valentina@bca.co.id',
#        'hadi_wiratama@bca.co.id', 'victor@algorit.ma',
#        'andreas_julianto@bca.co.id', 'hanny_hwang@bca.co.id',
#        'felisia_harisa@bca.co.id', 'setiawan_aliong@bca.co.id',
#        'mahardi_lie@bca.co.id', 'hanifareygina1@gmail.com',
#        'irdiansyah@econusa.id', 'sultanino99@gmail.com',
#        'tsubaety01@gmail.com', 'hilmi.dwiputranto@gmail.com',
#        'septiana.sacharinawati@cbn.or.id', 'avitakhilya27@gmail.com',
#        'dedenurheliza@gmail.com', 'david@algorit.ma',
#        'anastasia.wahyuni@cbn.or.id', 'farrelrassya40@gmail.com',
#        'garinzafira.shabrina@gmail.com', 'ganaover.sitanggang@gmail.com',
#        'mafarihan0709@pnm.co.id', 'dading.hadisurya@gmail.com',
#        'nasyaarsy97@gmail.com', 'prasnatama.ramadhan@gmail.com',
#        'laras.widyawati17@gmail.com', 'anggitnovietasarii@gmail.com',
#        'izdiharfabiola@gmail.com', 'atika.faradila@gmail.com',
#        'heriw03@gmail.com', 'bella.aptlk@gmail.com',
#        'shafirafebriyanti@student.telkomuniversity.ac.id',
#        'hey.dsi@gmail.com', 'mochiyamsjarif@gmail.com',
#        'andrewlieee@gmail.com', 'pratama.yogie0610@gmail.com',
#        'xunarto@gmail.com', 'tien.wahyuni@gmail.com',
#        'shg.gunawan@cloudgdrive.com', 'tbgs1201@gmail.com',
#        'hsurawijaya@gmail.com', 'cyc_ed@yahoo.com',
#        'alanafath123@gmail.com', 'naufal.nuh@gmail.com',
#        'cherinalarubatt@gmail.com', 'henrykruspe@gmail.com',
#        'bernadetgriselda@gmail.com', 'fibry@me.com',
#        'nadif@kitalulus.com', 'elsimanata.putro@gmail.com',
#        'hiyosuapg@gmail.com', 'daniel.syahputra@ui.ac.id',
#        'lydsinaga@gmail.com', 'jonathan.ariel.k@gmail.com',
#        'rakabrbl@gmail.com', 'aldinaanjani@gmail.com',
#        'lnurfaza01@gmail.com', 'sinarmulia2203@gmail.com',
#        'justinusdedy@gmail.com', 'yohanapolins@gmail.com',
#        'christiansiburian32@gmail.com', 'nathanielbenedict31@gmail.com',
#        'pratikto.tyas87@gmail.com', 'hartono@sinemart.com',
#        'hanugrah6@gmail.com', 'rezarsyahputra@gmail.com',
#        'rahmawidya1812@gmail.com', 'tafiaalifianty@gmail.com',
#        'yahma2204@gmail.com', 'nabilfzan0897@gmail.com',
#        'dyanafam37@gmail.com', 'official.erwinpasaribu@gmail.com',
#        'dmagita@cimbniaga.co.id', 'sandi.maruto@cimbniaga.co.id',
#        'yuniarandriani96@gmail.com', 'bayu_prakoso@telkomsel.co.id',
#        'arsyilhs@gmail.com', 'deshinta.cesaria@gmail.com',
#        'pandu.kedul@gmail.com', 'karinasasmitha@gmail.com',
#        'teraputera@gmail.com', 'irvandisihombing1001@gmail.com',
#        'aristidesariawan@gmail.com', 'yuki8999@gmail.com',
#        'vmahmud@gmail.com', 'intan.corina@bpjs-kesehatan.go.id',
#        'mcandra.ikhda@bpjs-kesehatan.go.id',
#        'rudy.ardian@bpjs-kesehatan.go.id',
#        'tedo.arya@bpjs-kesehatan.go.id', 'joe.takapente1408@gmail.com',
#        'hermawanpetra@gmail.com', 'rosmiati.vina@gmail.com',
#        'rasisimammudin@gmail.com', 'nirmalasanturi3@gmail.com',
#        'syarifah.rizki99@gmail.com', 'vincentius.kedang@gmail.com',
#        'adliferasa@gmail.com', 'harnsensia@gmail.com',
#        'dominicusibnu@gmail.com', 'dwinurf28@gmail.com',
#        'rianggaaden@gmail.com', 'julio19001@mail.unpad.ac.id',
#        'hafifcyber@gmail.com', 'indra.prakoso@cimbniaga.co.id',
#        'nirta.ika@gmail.com', 'eka.ratnawinarti86@gmail.com',
#        'ccalvintj@gmail.com', 'vania.rahma.g@gmail.com',
#        'jan.arifin@gmail.com', 'sutantothe12@gmail.com',
#        'haryono@gmail.com', 'gandhysutiono@gmail.com',
#        'taniasyahara25@gmail.com', 'yusmochammad@gmail.com',
#        'iwanevandersyema@gmail.com', 'nugroho.pramono@gmail.com',
#        'tesha_st@yahoo.com.sg', 'taufanrizkia@gmail.com',
#        'andika2812@gmail.com', 'arsyadamid.work@gmail.com',
#        'faldiena.m@apps.ipb.ac.id', 'mtaufiqashari@gmail.com',
#        'melia.sie83@gmail.com', 'baharudin.yudhi@infomedia.co.id',
#        'prameswari.ester.s@gmail.com', 'arorakshitijbir@gmail.com',
#        'johansetiawanhoe@gmail.com', 'umbu1311xyz@gmail.com',
#        'haris.ruhimat@gmail.com', 'sofiyanti@apps.ipb.ac.id',
#        'irvadwinovita@gmail.com', 'novanggraenii@gmail.com',
#        'frangkyezra31@gmail.com', 'agustiandra.lfc@gmail.com',
#        'dinar.mahandhira@gmail.com', 'fabianrichie@gmail.com',
#        'almer.krisnanda@gmail.com', 'kevinignatius8@gmail.com',
#        'vaniaandrianig04@gmail.com', 'miranthi.budiarti@gmail.com',
#        'lestarievelyn@gmail.com', 'anderafuardi24@gmail.com',
#        'riocasta2@gmail.com', 'joesepk@gmail.com',
#        'joshuaevan010196@gmail.com', 'hjantonius21@gmail.com',
#        'michelleradita1@gmail.com', 'tommy.william1297@gmail.com',
#        'nathalie.istanto97@gmail.com', 'doni.el.tobing@gmail.com',
#        'samuelmulia2@gmail.com', 'lita@algorit.ma',
#        'adyatama.arga@gmail.com', 'davidlimbonggg@gmail.com',
#        'trianinarita@gmail.com'], dtype=object)

# %%
try:

    service = build('sheets', 'v4', credentials=creds)
    values = [
        [
            # Cell values ...
        ],
        # Additional rows ...
    ]
    body = {
        'values': values
    }
    result = service.spreadsheets().values().update(
        spreadsheetId=spreadsheet_id, range=range_name,
        valueInputOption=value_input_option, body=body).execute()
    print(f"{result.get('updatedCells')} cells updated.")

except HttpError as error:
    print(f"An error occurred: {error}")

# %% [markdown]
# ### Draft Grades
#
# Submissions from the chosen quiz are going to be graded as **Draft Grade**

# %% [markdown]
# Use the `courses().courseWork().studentSubmissions().list()` method to store a list of the quiz's submissions

# %%
submissions = []

response = service.courses().courseWork().studentSubmissions().list(
    courseId=course_id,
    courseWorkId=quiz_id).execute()
submissions.extend(response.get('studentSubmissions', []))

while response.get('nextPageToken'):
    response = service.courses().courseWork().studentSubmissions().list(
        courseId=course_id,
        courseWorkId=quiz_id,
        pageToken = response['nextPageToken']).execute()
    submissions.extend(response.get('studentSubmissions'))

# %%
len(submissions)
# Out:
# 57

# %% [markdown]
# All the stored submission are graded as draft in accordance with the student's e-mail in the Google Classroom using `courses().courseWork().studentSubmissions().patch()` method

# %%
from assets import quizcode

draft = []
quiz_code = quizcode(quiz_input)

for submission in submissions:
  # Retrieve student's email
  submission_profile = service.courses().students().get(courseId=course_id, userId=submission['userId']).execute()
  student_df = df.loc[df['Email Classroom'] == submission_profile['profile']['emailAddress']]
  
  # Retrieve student's grade
  if not student_df.empty:
    if student_df[quiz_code].values[0].isnumeric():
      submission_grade = student_df[quiz_code].values[0]
    else:
      print(f"WARNING: {submission_profile['profile']['name']['fullName']} ({submission_profile['profile']['emailAddress']}) has no grade")
      draft.append([submission_profile['profile']['name']['fullName'], None, "NO GRADE"])
      continue      
  else:
    print(f"WARNING: {submission_profile['profile']['name']['fullName']} ({submission_profile['profile']['emailAddress']}) was not found")
    draft.append([submission_profile['profile']['name']['fullName'], None, "NOT FOUND"])
    continue

  # Grade the submission as draftGrade
  studentSubmission = {
    'draftGrade': str(submission_grade)
  }

  response = service.courses().courseWork().studentSubmissions().patch(
      courseId=course_id,
      courseWorkId=classwork['id'],
      id=submission['id'],
      updateMask='draftGrade',
      body = studentSubmission ).execute()
  
  draft.append([submission_profile['profile']['name']['fullName'], submission_grade, "GRADED"])

draft_df = pd.DataFrame(draft, columns=['Name', 'Grade', 'Status'])
draft_df
# Out:
# WARNING: Anastasya Algoritma (anastasya@algorit.ma) was not found
# WARNING: Sari Nurfiani (sari@algorit.ma) was not found
# WARNING: Algoritma Night (algostudentnight1@gmail.com) was not found
# WARNING: Geolana Wijayakusumah (geolana@algorit.ma) was not found
# WARNING: Mohammad De Syaeful (syaeful@algorit.ma) was not found
# WARNING: Charisma Omega Nafu (charisma@algorit.ma) was not found
# WARNING: Algoritma Day (algostudentday@gmail.com) was not found
# WARNING: Azzahra Putri Triarto (zahra@algorit.ma) was not found
# WARNING: Irsyad Akmala Mukhtar (irsyad.mukhtar@gmail.com) was not found
# WARNING: Famy Kurnia (famykurnia@gmail.com) was not found
# WARNING: rcaesario (idxriski.caesario@gmail.com) was not found
#                              Name Grade     Status
# 0                  Nissa Corlidea     2     GRADED
# 1        Cak Mustafa (cakmustafa)     2     GRADED
# 2             Shavira Zhalsabilla     2     GRADED
# 3                             Dea     2     GRADED
# 4                    Albertus MPP     2     GRADED
# 5                   Taufiq Rahman     2     GRADED
# 6         Pramadia Adhie Lazuardi     2     GRADED
# 7                Bintang Setyawan     0     GRADED
# 8                    Fajar khamim     2     GRADED
# 9           Grace Angela Sutantya     2     GRADED
# 10              Danadyaksa Wijaya     2     GRADED
# 11               Berliana Harahap     2     GRADED
# 12                    ridha rahmi     2     GRADED
# 13      Theophilos Adalrico Abadi     0     GRADED
# 14                 Ellen Setiawan     2     GRADED
# 15            Anas Fauzan Baletti     2     GRADED
# 16  Ihsan Azmi Rabbani (HeatAced)     2     GRADED
# 17                 Nadya Naftalia     2     GRADED
# 18              Ghozy Abror Aufan     2     GRADED
# 19                     Faza Aliya     2     GRADED
# 20                     Olivia Sim     2     GRADED
# 21                Bagus Pramudito     2     GRADED
# 22                gustaf yulianto     0     GRADED
# 23                   Fenny Martan     0     GRADED
# 24                Fransiska Pinem     2     GRADED
# 25                   Dimas Aditya     0     GRADED
# 26            Anastasya Algoritma  None  NOT FOUND
# 27             Jayadi butar-butar     2     GRADED
# 28                  Sari Nurfiani  None  NOT FOUND
# 29                Algoritma Night  None  NOT FOUND
# 30          Geolana Wijayakusumah  None  NOT FOUND
# 31            Mohammad De Syaeful  None  NOT FOUND
# 32            Charisma Omega Nafu  None  NOT FOUND
# 33              Nia Dewi Nofianti     2     GRADED
# 34                   Audi Chandra     2     GRADED
# 35         Farhan Zhafar Ramadhan     2     GRADED
# 36                      Lela Novi     2     GRADED
# 37                 Riyan Sasmytha     2     GRADED
# 38                 Luthfi Pratama     2     GRADED
# 39                  Pandu Working     2     GRADED
# 40                  Algoritma Day  None  NOT FOUND
# 41                  Melissa Rusli     2     GRADED
# 42            Taufan Anggoro Adhi     2     GRADED
# 43                Ranno Chairandy     2     GRADED
# 44                Hendry Julianto     2     GRADED
# 45                      Brenda Th     2     GRADED
# 46            Fathiyyah Maryufani     2     GRADED
# 47                  Wildan Hadziq     2     GRADED
# 48                   Calvin Gozal     2     GRADED
# 49          Azzahra Putri Triarto  None  NOT FOUND
# 50                Husna Aydadenta     2     GRADED
# 51                  Charles Kambu     0     GRADED
# 52                  satyo pradana     2     GRADED
# 53                   Louis Sirait     2     GRADED
# 54          Irsyad Akmala Mukhtar  None  NOT FOUND
# 55                    Famy Kurnia  None  NOT FOUND
# 56                      rcaesario  None  NOT FOUND

# %% [markdown]
# Confirm Draft Grade before continuing

# %%
confirmation = input('Return grades? [y]/[n] : ')
if confirmation.lower() == 'y':
    print("Returning student's grades")
else :
    raise Exception("Return cancelled")
# Out:
# Returning student's grades

# %% [markdown]
# ### Return Grades
#
# Submissions from the chosen quiz are going to be graded as **Assigned Grade**

# %% [markdown]
# All the stored submission are grades are **returned** in accordance with the student's e-mail in the Google Classroom using `courses().courseWork().studentSubmissions().patch()` method

# %%
try:
    for submission in submissions:
        # Retrieve student's email
        submission_profile = service.courses().students().get(courseId=course_id, userId=submission['userId']).execute()
        student_df = df.loc[df['Email Classroom'] == submission_profile['profile']['emailAddress']]
        
        # Retrieve student's grade
        if not student_df.empty:
            if student_df[quiz_code].values[0].isnumeric():
                submission_grade = student_df[quiz_code].values[0]
            else:
                continue
        else:
            continue
        
        # Grade the submission as assignedGrade
        studentSubmission = {
            'assignedGrade': str(submission_grade)
        }

        response = service.courses().courseWork().studentSubmissions().patch(
            courseId=course_id,
            courseWorkId=classwork['id'],
            id=submission['id'],
            updateMask='assignedGrade',
            body = studentSubmission).execute()
        
    print('Quiz grades was successfully returned')

except HttpError as error:
    print(error)
# Out:
# Quiz grades was successfully returned
